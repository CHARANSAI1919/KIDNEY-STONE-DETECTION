# %% [markdown]
# <a href="https://colab.research.google.com/github/CHARANSAI1919/KIDNEY-STONE-DETECTION/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="bpbNjVwja4Il77BzOK6n")
project = rf.workspace("kidney-ktlmt").project("kidney-stone-ultrasound")
version = project.version(1)
dataset = version.download("yolov7")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to kidney-stone-ultrasound-1 in yolov7pytorch:: 100%|██████████| 10874/10874 [00:02<00:00, 4158.23it/s]

# %%
# prompt: i imported the dataset, write the sample code to check if its working

import os

# Check if the dataset directory exists
dataset_path = os.path.join(os.getcwd(), "kidney-stone-ultrasound-1")
if os.path.exists(dataset_path):
  print(f"Dataset found at: {dataset_path}")

  # List files and subdirectories within the dataset directory
  for root, dirs, files in os.walk(dataset_path):
      level = root.replace(dataset_path, '').count(os.sep)
      indent = ' ' * 4 * (level)
      print('{}{}/'.format(indent, os.path.basename(root)))
      subindent = ' ' * 4 * (level + 1)
      for f in files:
          print('{}{}'.format(subindent, f))

else:
  print("Dataset directory not found.")
  print(f"Expected path: {dataset_path}")
  print("Please verify the dataset was downloaded correctly.")
# Out:
# Dataset found at: /content/kidney-stone-ultrasound-1
# kidney-stone-ultrasound-1/
#     data.yaml
#     README.dataset.txt
#     README.roboflow.txt
#     train/
#         labels/
#             normal-kidney-106-_shear_flip_jpg.rf.15d5d7de4d7ffc373a2353e1d3c43e5e.txt
#             kidimg-18-_jpg.rf.da1bc1607c239345e80cdeb842aafac4.txt
#             normal-kidney-87-_rotated_180_jpg.rf.afac0a65b80618f9a21038efb1d0dd38.txt
#             kidimg-4253-_jpg.rf.490ad8dfe3d45dc45c1f7f6d09c832f5.txt
#             normal-kidney-83-_shear_flip_jpg.rf.1bf20b816fe0a54fb4461d053d2ff355.txt
#             normal-kidney-76-_flipped_horizontal_jpg.rf.753533bab36c876ab60c44afa1b315f4.txt
#             kidimg-1219-_jpg.rf.33d8d9fd4ef45b4b6a33d1ddf1fb6c14.txt
#             kidimg-1541-_jpg.rf.e8fd44096ed8d305b55c555d174eaeb1.txt
#             f1377376ea878dfa20289e17d977ea_jpg.rf.63051475951174a036c46b29186dd763.txt
#             0001-N6FCLG0A_jpg.rf.797e0d6c1c245a4bd920810ec744b7b3.txt
# ...
